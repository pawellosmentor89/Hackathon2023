# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('result_prediction.csv')

# %%
df.head()
# Out:
#    i  j    prediction
# 0  0  0  7.825295e+36
# 1  0  1  7.825295e+36
# 2  0  2  7.825295e+36
# 3  0  3  7.825295e+36
# 4  0  4  7.825295e+36

# %%
df.tail()
# Out:
#           i    j    prediction
# 473195  699  671  7.825295e+36
# 473196  699  672  7.825295e+36
# 473197  699  673  7.825295e+36
# 473198  699  674  7.825295e+36
# 473199  699  675  7.825295e+36

# %%
df.info
# Out:
# <bound method DataFrame.info of           i    j    prediction
# 0         0    0  7.825295e+36
# 1         0    1  7.825295e+36
# 2         0    2  7.825295e+36
# 3         0    3  7.825295e+36
# 4         0    4  7.825295e+36
# ...     ...  ...           ...
# 473195  699  671  7.825295e+36
# 473196  699  672  7.825295e+36
# 473197  699  673  7.825295e+36
# 473198  699  674  7.825295e+36
# 473199  699  675  7.825295e+36
#
# [473200 rows x 3 columns]>

# %%
df.describe()
# Out:
#                    i              j    prediction
# count  473200.000000  473200.000000  4.732000e+05
# mean      349.500000     337.500000  6.259740e+35
# std       202.072602     195.144384  2.122875e+36
# min         0.000000       0.000000 -9.627855e-01
# 25%       174.750000     168.750000 -2.986788e-01
# 50%       349.500000     337.500000 -2.950996e-01
# 75%       524.250000     506.250000 -2.938300e-01
# max       699.000000     675.000000  7.825295e+36

# %%
# Wyświetlenie podstawowych informacji o danych
print("Podstawowe informacje o danych:")
print(df.info())

# Wyświetlenie statystyk opisowych dla kolumn numerycznych
print("\nStatystyki opisowe:")
print(df.describe())

# Wyświetlenie pierwszych 5 wierszy danych
print("\nPierwsze 5 wierszy:")
print(df.head())

# Wyświetlenie ostatnich 5 wierszy danych
print("\nOstatnie 5 wierszy:")
print(df.tail())

# Sprawdzenie brakujących wartości
print("\nLiczba brakujących wartości:")
print(df.isnull().sum())

# Usunięcie duplikatów
df.drop_duplicates(inplace=True)

# Wyświetlenie liczby unikalnych wartości w poszczególnych kolumnach
print("\nLiczba unikalnych wartości:")
print(df.nunique())

# Wyświetlenie histogramu dla wybranej kolumny
wybrana_kolumna = 'nazwa_kolumny'
df[wybrana_kolumna].hist()
plt.xlabel(wybrana_kolumna)
plt.ylabel("Liczba wystąpień")
plt.title("Histogram " + wybrana_kolumna)
plt.show()

# Wyświetlenie wykresu słupkowego dla wybranej kolumny
df[wybrana_kolumna].value_counts().plot(kind='bar')
plt.xlabel(wybrana_kolumna)
plt.ylabel("Liczba wystąpień")
plt.title("Wykres słupkowy " + wybrana_kolumna)
plt.show()

# Wyświetlenie macierzy korelacji dla kolumn numerycznych
print("\nMacierz korelacji:")
print(df.corr())

# Wyświetlenie wykresu korelacji
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Macierz korelacji")
plt.show()
# Out:
# Podstawowe informacje o danych:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473200 entries, 0 to 473199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   i           473200 non-null  int64
#  1   j           473200 non-null  int64
#  2   prediction  473200 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 10.8 MB
# None
#
# Statystyki opisowe:
#                    i              j    prediction
# count  473200.000000  473200.000000  4.732000e+05
# mean      349.500000     337.500000  6.259740e+35
# std       202.072602     195.144384  2.122875e+36
# min         0.000000       0.000000 -9.627855e-01
# 25%       174.750000     168.750000 -2.986788e-01
# 50%       349.500000     337.500000 -2.950996e-01
# 75%       524.250000     506.250000 -2.938300e-01
# max       699.000000     675.000000  7.825295e+36
#
# Pierwsze 5 wierszy:
#    i  j    prediction
# 0  0  0  7.825295e+36
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns]]]]]
df = pd.read_csv('result_prediction.csv')
print(df.info())
print(df.describe())
print(df.head())
print(df.tail())
print(df.isnull().sum())
df.drop_duplicates(inplace=True)
print(df.nunique())
print(df.corr())
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473200 entries, 0 to 473199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   i           473200 non-null  int64
#  1   j           473200 non-null  int64
#  2   prediction  473200 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 10.8 MB
# None
#                    i              j    prediction
# count  473200.000000  473200.000000  4.732000e+05
# mean      349.500000     337.500000  6.259740e+35
# std       202.072602     195.144384  2.122875e+36
# min         0.000000       0.000000 -9.627855e-01
# 25%       174.750000     168.750000 -2.986788e-01
# 50%       349.500000     337.500000 -2.950996e-01
# 75%       524.250000     506.250000 -2.938300e-01
# max       699.000000     675.000000  7.825295e+36
#    i  j    prediction
# 0  0  0  7.825295e+36
# 1  0  1  7.825295e+36
# 2  0  2  7.825295e+36
# 3  0  3  7.825295e+36
# ...
